# %%
# !pip install streamlit
# Out:
# ...
#      |████████████████████████████████| 10.1 MB 4.5 MB/s
# ...
#      |████████████████████████████████| 111 kB 45.5 MB/s
# ...
#      |████████████████████████████████| 76 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 181 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 164 kB 48.0 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 23.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 131 kB 36.9 MB/s
# ...
#      |████████████████████████████████| 130 kB 22.0 MB/s
# ...
#      |████████████████████████████████| 793 kB 33.2 MB/s
# ...
#      |████████████████████████████████| 428 kB 34.3 MB/s
# ...
#      |████████████████████████████████| 381 kB 38.2 MB/s
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=d96865a0a515c946af714ed775c556b0850f73287a166fdb04f7d07330329d2d
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# ...

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 745 kB 5.4 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=d4f8a5d0820054c0eac0b0d7e232a80f682b33d8868ceed724b9e68809317c5b
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...

# %%
# !ngrok authtoken 1xJScBDcoLWYNJrQzuvnaPvmO8u_3jYVMp3xw5PQakGTP5pJy
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
#mounting the google drive to import the dataset

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-24ad294961be> in <module>()
#       2
#       3 from google.colab import drive
# ----> 4 drive.mount('/content/drive/')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
# %%writefile app.py
import streamlit as st
import tensorflow as tf
import streamlit as st
import  tensorflow as tf
from tensorflow.keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import  os
import pandas as pd
from werkzeug.utils import secure_filename
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.ensemble import  RandomForestClassifier
import pickle
import h5py

@st.cache(allow_output_mutation=True)
def load_model():
  model=tf.keras.models.load_model('/content/drive/MyDrive/Speech-Emotion-Recognition-Adarsh Kumar/Models/vgg_fine_tuning.hdf5')
  return model
with st.spinner('Model is being loaded..'):
  model=load_model()

st.write("""
         # Speech Emotion Recognition
         """
         )

file = st.file_uploader("Please upload an audio file", type=["wav"])

import keras
import numpy as np
import librosa
import librosa.display

st.set_option('deprecation.showfileUploaderEncoding', False)
def save_spectrogram1(audio_fname):
    y, sr = librosa.load(audio_fname, sr=None)
    S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
    log_S = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')
    fig1 = plt.gcf()
    plt.axis('off')
    # plt.show()
    plt.draw()
    plt.close(fig1)
    image_fname="img"
    fig1.savefig(image_fname, dpi=200)
    return image_fname + ".png"
    
def  img_pred(img_path, model):
  img = image.load_img(img_path, target_size=(224, 224))
  x = image.img_to_array(img)
  x = np.true_divide(x, 255)
  x = np.expand_dims(x,axis=0)
  preds = model.predict(x)
  ans=np.argmax(preds)
  return ans

def mod_1(audio_fname,model):
    img_path = save_spectrogram1(audio_fname)
    ans = img_pred(img_path, model)
    return ans

def model_predict(audio_fname):
  d = ["angry", "calm", "disgusting", "fearful", 'happy', 'neutral', 'sad', 'surprised']
  ans=mod_1(audio_fname,model)
  return d[ans]

if file is None:
    st.text("Please upload an audio file")
else:
    predictions = model_predict(file)
    st.success(f"It seems like you're quite {predictions} today")
# Out:
# Writing app.py

# %%
from pyngrok import ngrok
url=ngrok.connect(port=8501)
url
# Out:
# <NgrokTunnel: "http://0437-34-125-31-197.ngrok.io" -> "http://localhost:80">

# %%
# !streamlit run --server.port 80 app.py >/dev/null
# Out:
# 2021-10-22 11:53:24.362789: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-22 11:53:24.362851: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (aa8621679df0): /proc/driver/nvidia/version does not exist
